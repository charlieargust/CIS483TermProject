# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import timedelta
from dateutil.relativedelta import relativedelta

from sklearn.preprocessing import MinMaxScaler

import torch
import torch.nn as nn

# %%
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# ### Importing Data & Exploring Structure

# %%
detroit_weather = pd.read_csv('daily_detroit_weather.csv')

detroit_weather.head()
# Out:
#        date  temperature_2m_max (F)  precipitation_sum (inch)  \
# 0  1/1/2000                    46.3                     0.000
# 1  1/2/2000                    53.9                     0.075
# 2  1/3/2000                    47.3                     0.406
# 3  1/4/2000                    48.8                     0.134
# 4  1/5/2000                    29.9                     0.000
#
#    snowfall_sum (inch)  relative_humidity_2m_mean (%)  dew_point_2m_mean (F)  \
# 0                  0.0                             74                   26.6
# 1                  0.0                             93                   44.4
# 2                  0.0                             94                   35.0
# 3                  0.0                             74                   29.0
# 4                  0.0                             57                   13.8
#
#    surface_pressure_mean (hPa)  wind_speed_10m_mean (mp/h)  \
# 0                        995.3                         8.8
# 1                        987.3                        14.3
# 2                        990.3                        11.6
# 3                        983.4                        16.5
# 4                       1003.6                         7.7
#
#    cloud_cover_mean (%)
# 0                    52
# 1                    85
# 2                    93
# 3                    95
# 4                    92

# %%
detroit_weather.shape
# Out:
# (9446, 9)

# %% [markdown]
# #### Datatypes, Missing Values, and Column Names

# %%
detroit_weather.dtypes
# Out:
# date                              object
# temperature_2m_max (F)           float64
# precipitation_sum (inch)         float64
# snowfall_sum (inch)              float64
# relative_humidity_2m_mean (%)      int64
# dew_point_2m_mean (F)            float64
# surface_pressure_mean (hPa)      float64
# wind_speed_10m_mean (mp/h)       float64
# cloud_cover_mean (%)               int64
# dtype: object

# %% [markdown]
# All variables are of acceptable data types, with the exception of `temperature_2m ((°F)` which will be converted to a pandas `datetime64` object

# %%
detroit_weather['date'] = pd.to_datetime(detroit_weather['date'])

# %%
detroit_weather.describe()
# Out:
#                       date  temperature_2m_max (F)  precipitation_sum (inch)  \
# count                 9446             9446.000000               9446.000000
# mean   2012-12-05 12:00:00               57.667531                  0.096158
# min    2000-01-01 00:00:00               -4.500000                  0.000000
# 25%    2006-06-19 06:00:00               40.900000                  0.000000
# 50%    2012-12-05 12:00:00               58.900000                  0.004000
# 75%    2019-05-24 18:00:00               75.500000                  0.087000
# max    2025-11-10 00:00:00              100.100000                  2.232000
# std                    NaN               19.865220                  0.207118
#
#        snowfall_sum (inch)  relative_humidity_2m_mean (%)  \
# count          9446.000000                    9446.000000
# mean              0.075790                      71.416790
# min               0.000000                      34.000000
# 25%               0.000000                      64.000000
# 50%               0.000000                      72.000000
# 75%               0.000000                      79.000000
# max               7.661000                      99.000000
# std               0.379708                      10.825426
#
#        dew_point_2m_mean (F)  surface_pressure_mean (hPa)  \
# count            9446.000000                  9446.000000
# mean               40.844760                   994.842357
# min               -16.800000                   966.300000
# 25%                27.000000                   990.700000
# 50%                41.800000                   994.900000
# 75%                56.900000                   999.000000
# max                75.600000                  1019.700000
# std                18.691149                     6.685341
#
#        wind_speed_10m_mean (mp/h)  cloud_cover_mean (%)
# count                 9446.000000           9446.000000
# mean                     9.495469             61.287423
# min                      1.900000              0.000000
# 25%                      6.800000             39.000000
# 50%                      9.000000             66.000000
# 75%                     11.800000             87.000000
# max                     26.400000            100.000000
# std                      3.626255             29.219403

# %% [markdown]
# ### Splitting Data into Train & Test

# %%
val_split_idx = int(0.8 * len(detroit_weather))
test_split_idx = int(0.9 * len(detroit_weather))

val_split_date = detroit_weather.iloc[val_split_idx, 0]
test_split_date = detroit_weather.iloc[test_split_idx, 0]

# %%
train_df = detroit_weather.iloc[:val_split_idx]
val_df = detroit_weather.iloc[val_split_idx:test_split_idx]
test_df = detroit_weather.iloc[test_split_idx:]

print(f'Training Date Range: ({train_df['date'].min()}) → ({train_df['date'].max()})')
print(f'Validation Date Range: ({val_df['date'].min()}) → ({val_df['date'].max()})')
print(f'Testing Date Range: ({test_df['date'].min()}) → ({test_df['date'].max()})')
# Out:
# Training Date Range: (2000-01-01 00:00:00) → (2020-09-07 00:00:00)
# Validation Date Range: (2020-09-08 00:00:00) → (2023-04-10 00:00:00)
# Testing Date Range: (2023-04-11 00:00:00) → (2025-11-10 00:00:00)

# %% [markdown]
# ### Baseline Models

# %% [markdown]
# #### Naive

# %%
actual = detroit_weather['temperature_2m_max (F)'].to_numpy()

testing_actual = actual[test_split_idx:]
naive_predictions = np.roll(actual, 1)[test_split_idx:]

# %%
plt.figure(figsize=(14, 6))

# training data for last 100 days
plt.plot(train_df['date'], train_df['temperature_2m_max (F)'], label='Training Data')
plt.plot(val_df['date'], val_df['temperature_2m_max (F)'], label = 'Validation Data')

# Naive forecast values
plt.plot(test_df['date'], naive_predictions, label='Naive Forecast', linestyle = '--')
plt.plot(test_df['date'], test_df['temperature_2m_max (F)'], label='Actual (Test)', alpha=0.2, color = 'grey')

plt.suptitle('7 Day Forecast with Simple Baseline Models', y = 0.95, fontsize = 14)
plt.title('Naive, Seasonal Naive, and Random Walk', fontsize = 10)
plt.xlabel('Date'); plt.ylabel('Temperature (°F)')

plt.legend()
plt.xticks(rotation = 45)
plt.show()

# %%
naive_mse = np.sqrt(np.mean(np.square(testing_actual - naive_predictions)))

print(f'MSE for Naive model: {naive_mse}')
# Out:
# MSE for Naive model: 7.128903831674954

# %% [markdown]
# ### Univariate LSTM - Predicting Temperature Using Previous `t` Days

# %%
# hyperparameters
lookback = 7
batch_size = 64
hidden_size = 32
num_layers = 1
dropout_rate = 0.1
learning_rate = 0.0001
num_epochs = 100

# %%
# seasonal sine and cosine waves
detroit_weather['day_of_year'] = detroit_weather['date'].dt.dayofyear
detroit_weather['sin_doy'] = np.sin(2 * np.pi * detroit_weather['day_of_year'] / 365.25)
detroit_weather['cos_doy'] = np.cos(2 * np.pi * detroit_weather['day_of_year'] / 365.25)

# %%
detroit_weather
# Out:
#            date  temperature_2m_max (F)  precipitation_sum (inch)  \
# 0    2000-01-01                    46.3                     0.000
# 1    2000-01-02                    53.9                     0.075
# 2    2000-01-03                    47.3                     0.406
# 3    2000-01-04                    48.8                     0.134
# 4    2000-01-05                    29.9                     0.000
# ...         ...                     ...                       ...
# 9441 2025-11-06                    50.7                     0.000
# 9442 2025-11-07                    56.3                     0.213
# 9443 2025-11-08                    46.0                     0.016
# 9444 2025-11-09                    38.6                     0.614
# 9445 2025-11-10                    31.7                     0.020
#
#       snowfall_sum (inch)  relative_humidity_2m_mean (%)  \
# 0                   0.000                             74
# 1                   0.000                             93
# 2                   0.000                             94
# 3                   0.000                             74
# 4                   0.000                             57
# ...                   ...                            ...
# 9441                0.000                             63
# 9442                0.000                             71
# 9443                0.000                             73
# 9444                2.728                             93
# 9445                0.138                             74
#
#       dew_point_2m_mean (F)  surface_pressure_mean (hPa)  \
# 0                      26.6                        995.3
# 1                      44.4                        987.3
# 2                      35.0                        990.3
# 3                      29.0                        983.4
# 4                      13.8                       1003.6
# ...                     ...                          ...
# 9441                   30.8                        998.9
# 9442                   40.2                        981.2
# 9443                   33.7                        988.5
# 9444                   32.7                        990.4
# 9445                   20.3                        995.3
#
#       wind_speed_10m_mean (mp/h)  cloud_cover_mean (%)  day_of_year   sin_doy  \
# 0                            8.8                    52            1  0.017202
# 1                           14.3                    85            2  0.034398
# 2                           11.6                    93            3  0.051584
# 3                           16.5                    95            4  0.068755
# 4                            7.7                    92            5  0.085906
# ...                          ...                   ...          ...       ...
# 9441                         5.8                    49          310 -0.813668
# 9442                        11.4                    67          311 -0.803548
# 9443                         6.2                    96          312 -0.793190
# 9444                        11.3                   100          313 -0.782597
# 9445                        11.3                    58          314 -0.771773
#
#        cos_doy
# 0     0.999852
# 1     0.999408
# 2     0.998669
# 3     0.997634
# 4     0.996303
# ...        ...
# 9441  0.581330
# 9442  0.595240
# 9443  0.608975
# 9444  0.622529
# 9445  0.635898
#
# [9446 rows x 12 columns]

# %%
plt.figure(figsize = (14,6))
plt.plot(detroit_weather['date'], detroit_weather['sin_doy'])
plt.plot(detroit_weather['date'], detroit_weather['cos_doy'])
plt.show()

# %%
feature_subset = detroit_weather[['date', 'temperature_2m_max (F)',
                                  'sin_doy', 'cos_doy']] # subset to include only datetime and temperature

feature_subset.head(13)
# Out:
#          date  temperature_2m_max (F)   sin_doy   cos_doy
# 0  2000-01-01                    46.3  0.017202  0.999852
# 1  2000-01-02                    53.9  0.034398  0.999408
# 2  2000-01-03                    47.3  0.051584  0.998669
# 3  2000-01-04                    48.8  0.068755  0.997634
# 4  2000-01-05                    29.9  0.085906  0.996303
# 5  2000-01-06                    37.4  0.103031  0.994678
# 6  2000-01-07                    30.9  0.120126  0.992759
# 7  2000-01-08                    42.0  0.137185  0.990545
# 8  2000-01-09                    38.2  0.154204  0.988039
# 9  2000-01-10                    44.7  0.171177  0.985240
# 10 2000-01-11                    40.0  0.188099  0.982150
# 11 2000-01-12                    32.5  0.204966  0.978769
# 12 2000-01-13                    27.1  0.221772  0.975099

# %% [markdown]
# #### Array Manipulation & Reshaping

# %%
from copy import deepcopy as dc

def prepare_dataframe_for_lstm(df, n_steps):
    df = dc(df)

    df.set_index('date', inplace=True)

    # for each date, there are 't - n_steps' previous days data
    for i in range(1, n_steps+1):
        df[f'Temperature (t-{i})'] = df['temperature_2m_max (F)'].shift(i)

    df.dropna(inplace=True)

    return df

# %%
shifted_df = prepare_dataframe_for_lstm(feature_subset, lookback)
shifted_df.head()
# Out:
#             temperature_2m_max (F)   sin_doy   cos_doy  Temperature (t-1)  \
# date
# 2000-01-08                    42.0  0.137185  0.990545               30.9
# 2000-01-09                    38.2  0.154204  0.988039               42.0
# 2000-01-10                    44.7  0.171177  0.985240               38.2
# 2000-01-11                    40.0  0.188099  0.982150               44.7
# 2000-01-12                    32.5  0.204966  0.978769               40.0
#
#             Temperature (t-2)  Temperature (t-3)  Temperature (t-4)  \
# date
# 2000-01-08               37.4               29.9               48.8
# 2000-01-09               30.9               37.4               29.9
# 2000-01-10               42.0               30.9               37.4
# 2000-01-11               38.2               42.0               30.9
# 2000-01-12               44.7               38.2               42.0
#
#             Temperature (t-5)  Temperature (t-6)  Temperature (t-7)
# date
# 2000-01-08               47.3               53.9               46.3
# 2000-01-09               48.8               47.3               53.9
# 2000-01-10               29.9               48.8               47.3
# 2000-01-11               37.4               29.9               48.8
# 2000-01-12               30.9               37.4               29.9

# %%
shifted_df_as_np = shifted_df.to_numpy()

shifted_df_as_np # rows are datetimes, columns are max temperatures of previous day
# Out:
# array([[42.        ,  0.1371854 ,  0.99054539, ..., 47.3       ,
#         53.9       , 46.3       ],
#        [38.2       ,  0.15420405,  0.98803902, ..., 48.8       ,
#         47.3       , 53.9       ],
#        [44.7       ,  0.17117706,  0.98524028, ..., 29.9       ,
#         48.8       , 47.3       ],
#        ...,
#        [46.        , -0.79318968,  0.60897465, ..., 57.        ,
#         54.3       , 51.        ],
#        [38.6       , -0.782597  ,  0.62252866, ..., 59.4       ,
#         57.        , 54.3       ],
#        [31.7       , -0.77177274,  0.63589845, ..., 59.4       ,
#         59.4       , 57.        ]])

# %%
# extract X, y
X = shifted_df_as_np[:, 1:]
y = shifted_df_as_np[:, 0]

X.shape, y.shape
# Out:
# ((9439, 9), (9439,))

# %%
seasonal_encodings = X[:, :2]
seq_features = X[:, 2:]

# %%
# switches order from Temp, Temp (t-1), Temp (t-2)... -> Temp, Temp(t-7), Temp(t-6)...
seq_features = np.flip(seq_features, axis = 1)
seq_features = seq_features.reshape(-1, lookback, 1)

seasonal_repeated = np.repeat(seasonal_encodings[:, np.newaxis, :], lookback, axis = 1)

X_final = np.concatenate([seq_features, seasonal_repeated], axis = 2)

X_final.shape
# Out:
# (9439, 7, 3)

# %%
X_train = X_final[:val_split_idx - lookback]
X_val = X_final[val_split_idx -lookback : test_split_idx - lookback]
X_test = X_final[test_split_idx - lookback:]

y_train = y[:val_split_idx - lookback]
y_val = y[val_split_idx - lookback : test_split_idx - lookback]
y_test = y[test_split_idx - lookback:]

X_train.shape, X_val.shape, X_test.shape, y_train.shape, y_val.shape, y_test.shape
# Out:
# ((7549, 7, 3), (945, 7, 3), (945, 7, 3), (7549,), (945,), (945,))

# %%
scaler_X = MinMaxScaler((-1,1))
X_train_scaled = scaler_X.fit_transform(X_train.reshape(-1, 3)).reshape(-1, lookback, 3)
X_val_scaled   = scaler_X.transform(X_val.reshape(-1, 3)).reshape(-1, lookback, 3)
X_test_scaled  = scaler_X.transform(X_test.reshape(-1, 3)).reshape(-1, lookback, 3)

scaler_y = MinMaxScaler((-1,1))
y_train_scaled = scaler_y.fit_transform(y_train.reshape(-1,1))
y_val_scaled   = scaler_y.transform(y_val.reshape(-1,1))
y_test_scaled  = scaler_y.transform(y_test.reshape(-1,1))

X_train_scaled.shape, X_test_scaled.shape, y_train_scaled.shape, y_test_scaled.shape
# Out:
# ((7549, 7, 3), (945, 7, 3), (7549, 1), (945, 1))

# %%
X_train = torch.tensor(X_train_scaled).float()
X_val = torch.tensor(X_val_scaled).float()
X_test = torch.tensor(X_test_scaled).float()

y_train = torch.tensor(y_train_scaled).float()
y_val = torch.tensor(y_val_scaled).float()
y_test = torch.tensor(y_test_scaled).float()

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# (torch.Size([7549, 7, 3]),
#  torch.Size([945, 7, 3]),
#  torch.Size([7549, 1]),
#  torch.Size([945, 1]))

# %% [markdown]
# #### Convert to Torch Dataset Object

# %%
from torch.utils.data import Dataset

class SimpleLSTMDataset(Dataset):
  def __init__(self, X, y):
    self.X = X
    self.y = y

  def __len__(self):
    return len(self.X)

  def __getitem__(self, i):
    return self.X[i], self.y[i]

train_dataset = SimpleLSTMDataset(X_train, y_train)
val_dataset = SimpleLSTMDataset(X_val, y_val)
test_dataset = SimpleLSTMDataset(X_test, y_test)

# %%
from torch.utils.data import DataLoader

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=256, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=256, shuffle=False)

# %% [markdown]
# ### Initalizing LSTM Class

# %%
class LSTM(nn.Module):
  # input_size: number of features, which is 1 for this edition
  # hidden_size: dimensionality of hidden state vector
  # num_stacked_layers: # of gate blocks stacked on top of each other
    def __init__(self, input_size, hidden_size, num_stacked_layers, dropout_rate = 0.2):
        super().__init__()
        self.hidden_size = hidden_size
        self.num_stacked_layers = num_stacked_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_stacked_layers, batch_first=True)

        self.dropout = nn.Dropout(p = dropout_rate)
        # will map from size of hidden to 1 (final predicted max temperature)
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
      # x = (batch, seq_len, input_size)
        batch_size = x.size(0)
        h0 = torch.zeros(self.num_stacked_layers, batch_size, self.hidden_size).to(device) # short-term memory
        c0 = torch.zeros(self.num_stacked_layers, batch_size, self.hidden_size).to(device) # long-term memory


        out, _ = self.lstm(x, (h0, c0)) # hidden state at every time step
        out = self.dropout(out)
        out = self.fc(out[:, -1, :]) # keeps only the last hidden state and maps to 1 prediction
        return out

model = LSTM(input_size = 3,
             hidden_size = hidden_size,
             num_stacked_layers = num_layers,
             dropout_rate = dropout_rate)
model.to(device)
model
# Out:
# LSTM(
#   (lstm): LSTM(3, 32, batch_first=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (fc): Linear(in_features=32, out_features=1, bias=True)
# )

# %%
loss_function = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

@torch.no_grad()
def evaluate(loader):
  model.eval()
  running_loss = 0.0

  for x, y in loader:
    x, y = x.to(device), y.to(device)

    output = model(x)
    loss = loss_function(output, y)
    running_loss += loss.item() * x.size(0) # multiplying by batch size

  return running_loss / len(loader.dataset)

# %%
train_losses = []; val_losses = []

def main():
  for epoch in range(1, num_epochs + 1):
    model.train()
    running_loss = 0.0

    for x, y in train_loader:
      x, y = x.to(device), y.to(device)

      optimizer.zero_grad()
      output = model(x)
      loss = loss_function(output, y)
      loss.backward()

      torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm = 1.0)

      optimizer.step()

      running_loss += loss.item() * x.size(0)

    train_loss = running_loss / len(train_loader.dataset)
    val_loss = evaluate(val_loader)

    train_losses.append(train_loss); val_losses.append(val_loss)

    print(f"Epoch {epoch:2d} | train_loss={train_loss:.4f} | val_loss={val_loss:.4f}")

if __name__ == '__main__':
  main()
# Out:
# Epoch  1 | train_loss=0.1362 | val_loss=0.1100
# Epoch  2 | train_loss=0.0844 | val_loss=0.0573
# Epoch  3 | train_loss=0.0388 | val_loss=0.0299
# Epoch  4 | train_loss=0.0269 | val_loss=0.0285
# Epoch  5 | train_loss=0.0254 | val_loss=0.0282
# Epoch  6 | train_loss=0.0252 | val_loss=0.0278
# Epoch  7 | train_loss=0.0250 | val_loss=0.0277
# Epoch  8 | train_loss=0.0244 | val_loss=0.0271
# Epoch  9 | train_loss=0.0244 | val_loss=0.0270
# Epoch 10 | train_loss=0.0238 | val_loss=0.0270
# Epoch 11 | train_loss=0.0239 | val_loss=0.0267
# Epoch 12 | train_loss=0.0234 | val_loss=0.0262
# Epoch 13 | train_loss=0.0232 | val_loss=0.0258
# Epoch 14 | train_loss=0.0230 | val_loss=0.0261
# Epoch 15 | train_loss=0.0226 | val_loss=0.0252
# Epoch 16 | train_loss=0.0226 | val_loss=0.0253
# Epoch 17 | train_loss=0.0224 | val_loss=0.0255
# Epoch 18 | train_loss=0.0220 | val_loss=0.0252
# Epoch 19 | train_loss=0.0220 | val_loss=0.0247
# Epoch 20 | train_loss=0.0218 | val_loss=0.0248
# Epoch 21 | train_loss=0.0216 | val_loss=0.0242
# Epoch 22 | train_loss=0.0212 | val_loss=0.0245
# Epoch 23 | train_loss=0.0210 | val_loss=0.0241
# Epoch 24 | train_loss=0.0211 | val_loss=0.0239
# Epoch 25 | train_loss=0.0209 | val_loss=0.0239
# Epoch 26 | train_loss=0.0210 | val_loss=0.0237
# Epoch 27 | train_loss=0.0206 | val_loss=0.0234
# Epoch 28 | train_loss=0.0203 | val_loss=0.0234
# Epoch 29 | train_loss=0.0203 | val_loss=0.0233
# Epoch 30 | train_loss=0.0201 | val_loss=0.0231
# Epoch 31 | train_loss=0.0201 | val_loss=0.0231
# Epoch 32 | train_loss=0.0201 | val_loss=0.0229
# Epoch 33 | train_loss=0.0200 | val_loss=0.0227
# Epoch 34 | train_loss=0.0198 | val_loss=0.0229
# Epoch 35 | train_loss=0.0197 | val_loss=0.0224
# Epoch 36 | train_loss=0.0193 | val_loss=0.0222
# Epoch 37 | train_loss=0.0195 | val_loss=0.0225
# Epoch 38 | train_loss=0.0193 | val_loss=0.0222
# Epoch 39 | train_loss=0.0191 | val_loss=0.0220
# Epoch 40 | train_loss=0.0192 | val_loss=0.0221
# Epoch 41 | train_loss=0.0189 | val_loss=0.0218
# Epoch 42 | train_loss=0.0187 | val_loss=0.0218
# Epoch 43 | train_loss=0.0189 | val_loss=0.0215
# Epoch 44 | train_loss=0.0187 | val_loss=0.0215
# Epoch 45 | train_loss=0.0187 | val_loss=0.0214
# Epoch 46 | train_loss=0.0186 | val_loss=0.0215
# Epoch 47 | train_loss=0.0184 | val_loss=0.0213
# Epoch 48 | train_loss=0.0182 | val_loss=0.0212
# Epoch 49 | train_loss=0.0181 | val_loss=0.0210
# Epoch 50 | train_loss=0.0182 | val_loss=0.0211
# Epoch 51 | train_loss=0.0180 | val_loss=0.0210
# Epoch 52 | train_loss=0.0180 | val_loss=0.0210
# Epoch 53 | train_loss=0.0178 | val_loss=0.0207
# Epoch 54 | train_loss=0.0178 | val_loss=0.0206
# Epoch 55 | train_loss=0.0176 | val_loss=0.0207
# Epoch 56 | train_loss=0.0174 | val_loss=0.0206
# Epoch 57 | train_loss=0.0176 | val_loss=0.0205
# Epoch 58 | train_loss=0.0173 | val_loss=0.0203
# Epoch 59 | train_loss=0.0173 | val_loss=0.0203
# Epoch 60 | train_loss=0.0173 | val_loss=0.0202
# Epoch 61 | train_loss=0.0171 | val_loss=0.0201
# Epoch 62 | train_loss=0.0169 | val_loss=0.0201
# Epoch 63 | train_loss=0.0170 | val_loss=0.0200
# Epoch 64 | train_loss=0.0168 | val_loss=0.0199
# Epoch 65 | train_loss=0.0168 | val_loss=0.0197
# Epoch 66 | train_loss=0.0167 | val_loss=0.0197
# Epoch 67 | train_loss=0.0167 | val_loss=0.0196
# Epoch 68 | train_loss=0.0166 | val_loss=0.0196
# Epoch 69 | train_loss=0.0163 | val_loss=0.0195
# Epoch 70 | train_loss=0.0163 | val_loss=0.0195
# Epoch 71 | train_loss=0.0163 | val_loss=0.0195
# Epoch 72 | train_loss=0.0162 | val_loss=0.0194
# Epoch 73 | train_loss=0.0161 | val_loss=0.0193
# Epoch 74 | train_loss=0.0162 | val_loss=0.0191
# Epoch 75 | train_loss=0.0161 | val_loss=0.0191
# Epoch 76 | train_loss=0.0160 | val_loss=0.0193
# Epoch 77 | train_loss=0.0159 | val_loss=0.0190
# Epoch 78 | train_loss=0.0160 | val_loss=0.0190
# Epoch 79 | train_loss=0.0159 | val_loss=0.0190
# Epoch 80 | train_loss=0.0159 | val_loss=0.0189
# Epoch 81 | train_loss=0.0157 | val_loss=0.0192
# Epoch 82 | train_loss=0.0157 | val_loss=0.0189
# Epoch 83 | train_loss=0.0157 | val_loss=0.0188
# Epoch 84 | train_loss=0.0157 | val_loss=0.0189
# Epoch 85 | train_loss=0.0154 | val_loss=0.0187
# Epoch 86 | train_loss=0.0155 | val_loss=0.0189
# Epoch 87 | train_loss=0.0154 | val_loss=0.0187
# Epoch 88 | train_loss=0.0155 | val_loss=0.0188
# Epoch 89 | train_loss=0.0154 | val_loss=0.0186
# Epoch 90 | train_loss=0.0152 | val_loss=0.0187
# Epoch 91 | train_loss=0.0154 | val_loss=0.0186
# Epoch 92 | train_loss=0.0153 | val_loss=0.0187
# Epoch 93 | train_loss=0.0153 | val_loss=0.0186
# Epoch 94 | train_loss=0.0153 | val_loss=0.0187
# Epoch 95 | train_loss=0.0153 | val_loss=0.0187
# Epoch 96 | train_loss=0.0152 | val_loss=0.0186
# Epoch 97 | train_loss=0.0154 | val_loss=0.0187
# Epoch 98 | train_loss=0.0153 | val_loss=0.0186
# Epoch 99 | train_loss=0.0151 | val_loss=0.0186
# Epoch 100 | train_loss=0.0152 | val_loss=0.0186

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.plot(train_losses, label="Training Loss", linewidth=2)
plt.plot(val_losses, label="Validation Loss", linewidth=2)
plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %%
@torch.no_grad()
def predict_with_dates(loader, dates, scaler):
    model.eval()
    preds = []
    actuals = []

    for x, y in loader:
        x, y = x.to(device), y.to(device)
        output = model(x)

        preds.append(output.cpu().numpy())
        actuals.append(y.cpu().numpy())

    preds = np.concatenate(preds).flatten().reshape(-1, 1)
    actuals = np.concatenate(actuals).flatten().reshape(-1, 1)

    # inverse transform
    preds_inv = scaler.inverse_transform(preds)
    actuals_inv = scaler.inverse_transform(actuals)

    # keep dates
    date_values = dates.iloc[-len(preds):].to_numpy()

    return preds_inv.flatten(), actuals_inv.flatten(), date_values

# %%
test_preds_inv, test_actual_inv, test_dates = predict_with_dates(
    test_loader,
    test_df['date'],
    scaler_y
)

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(test_actual_inv, test_preds_inv))
print(f"Test RMSE (original scale): {rmse:.4f} °F")
# Out:
# Test RMSE (original scale): 6.4601 °F

# %%
plt.figure(figsize=(14,6))
plt.plot(test_dates, test_actual_inv, label="Actual", linewidth=2)
plt.plot(test_dates, test_preds_inv, label="Predicted", linewidth=2)
plt.xlabel("Date")
plt.ylabel("Max Temperature (°F)")
plt.title("Actual vs Predicted Daily Max Temperature — Test Set")
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
